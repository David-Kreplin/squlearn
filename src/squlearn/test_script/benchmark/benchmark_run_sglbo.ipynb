# %%
from squlearn.optimizers import Adam, SGLBO
import numpy as np
from benchmark_functions import *

# %%
bo_x0 = [[i * 0.02] for i in range(15)]
config = {"bo_aqc_func": "EI", "bo_aqc_optimizer": "lbfgs", "bo_bounds": [(0.0, 0.0003)], "log_file": "sglbo.log",
                     "bo_n_calls": 30, "bo_x0_points": bo_x0, "maxiter": 100, "bo_bounds_fac": 0}
sglbo = SGLBO(config)

x0 = np.random.uniform(0, 5, 6)

sglbo.minimize(rosenbrock_function, x0)
# Out:
# BOP  fval:  82457.90332179217  x:  [0.0]
# BOP  fval:  40922.79410829746  x:  [1.9999999999999998e-05]
# BOP  fval:  18480.16208767173  x:  [3.9999999999999996e-05]
# BOP  fval:  8354.525143079649  x:  [5.9999999999999995e-05]
# BOP  fval:  5233.704987302669  x:  [7.999999999999999e-05]
# BOP  fval:  5268.827162739138  x:  [9.999999999999999e-05]
# BOP  fval:  6074.321041404261  x:  [0.00011999999999999999]
# BOP  fval:  6727.919824930109  x:  [0.00014]
# BOP  fval:  7770.660544565606  x:  [0.00015999999999999999]
# BOP  fval:  11206.88406117656  x:  [0.00017999999999999998]
# BOP  fval:  20504.235065245615  x:  [0.00019999999999999998]
# BOP  fval:  40593.662076872264  x:  [0.00021999999999999995]
# BOP  fval:  77869.41744577304  x:  [0.00023999999999999998]
# BOP  fval:  140189.05735128088  x:  [0.00026]
# BOP  fval:  236873.44180234626  x:  [0.00028]
# BOP  fval:  10630.851192331584  x:  [0.00017785338546750552]
# BOP  fval:  115908.56199294419  x:  [0.00025327972457430526]
# ...
